# %%
# !pip install httplib2
# Out:
# Collecting httplib2
#   Downloading httplib2-0.18.1-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 3.0 MB/s eta 0:00:01
# Installing collected packages: httplib2
# Successfully installed httplib2-0.18.1
# WARNING: You are using pip version 20.1.1; however, version 20.2.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import httplib2
import webbrowser
from pprint import pprint

# %%
bin_url = 'https://httpbin.org'

# %%
webbrowser.open(bin_url)
# Out:
# True

# %%
http = httplib2.Http()

# %%
resp, data = http.request(bin_url)

# %%
resp
# Out:
# {'date': 'Sun, 09 Aug 2020 14:22:08 GMT',
#  'content-type': 'text/html; charset=utf-8',
#  'content-length': '9593',
#  'connection': 'keep-alive',
#  'server': 'gunicorn/19.9.0',
#  'access-control-allow-origin': '*',
#  'access-control-allow-credentials': 'true',
#  'status': '200',
#  'content-location': 'https://httpbin.org'}

# %%
data
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <meta charset="UTF-8">\n    <title>httpbin.org</title>\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,600,700"\n        rel="stylesheet">\n    <link rel="stylesheet" type="text/css" href="/flasgger_static/swagger-ui.css">\n    <link rel="icon" type="image/png" href="/static/favicon.ico" sizes="64x64 32x32 16x16" />\n    <style>\n        html {\n            box-sizing: border-box;\n            overflow: -moz-scrollbars-vertical;\n            overflow-y: scroll;\n        }\n\n        *,\n        *:before,\n        *:after {\n            box-sizing: inherit;\n        }\n\n        body {\n            margin: 0;\n            background: #fafafa;\n        }\n    </style>\n</head>\n\n<body>\n    <a href="https://github.com/requests/httpbin" class="github-corner" aria-label="View source on Github">\n        <svg width="80" height="80" viewBox="0 0 250 250" style="fill:#151513; color:#fff; position: absolute; top: 0; border: 0; right: 0;"\n            aria-hidden="true">\n            <path d="M0,0 L115,115 L130,115 L142,142 L250,250 L250,0 Z"></path>\n            <path d="M128.3,109.0 C113.8,99.7 119.0,89.6 119.0,89.6 C122.0,82.7 120.5,78.6 120.5,78.6 C119.2,72.0 123.4,76.3 123.4,76.3 C127.3,80.9 125.5,87.3 125.5,87.3 C122.9,97.6 130.6,101.9 134.4,103.2"\n                fill="currentColor" style="transform-origin: 130px 106px;" class="octo-arm"></path>\n            <path d="M115.0,115.0 C114.9,115.1 118.7,116.5 119.8,115.4 L133.7,101.6 C136.9,99.2 139.9,98.4 142.2,98.6 C133.8,88.0 127.5,74.4 143.8,58.0 C148.5,53.4 154.0,51.2 159.7,51.0 C160.3,49.4 163.2,43.6 171.4,40.1 C171.4,40.1 176.1,42.5 178.8,56.2 C183.1,58.6 187.2,61.8 190.9,65.4 C194.5,69.0 197.7,73.2 200.1,77.6 C213.8,80.2 216.3,84.9 216.3,84.9 C212.7,93.1 206.9,96.0 205.4,96.6 C205.1,102.4 203.0,107.8 198.3,112.5 C181.9,128.9 168.3,122.5 157.7,114.1 C157.9,116.9 156.7,120.9 152.7,124.9 L141.0,136.5 C139.8,137.7 141.6,141.9 141.8,141.8 Z"\n                fill="currentColor" class="octo-body"></path>\n        </svg>\n    </a>\n    <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="position:absolute;width:0;height:0">\n        <defs>\n            <symbol viewBox="0 0 20 20" id="unlocked">\n                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V6h2v-.801C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8z"></path>\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="locked">\n                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8zM12 8H8V5.199C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8z"\n                />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="close">\n                <path d="M14.348 14.849c-.469.469-1.229.469-1.697 0L10 11.819l-2.651 3.029c-.469.469-1.229.469-1.697 0-.469-.469-.469-1.229 0-1.697l2.758-3.15-2.759-3.152c-.469-.469-.469-1.228 0-1.697.469-.469 1.228-.469 1.697 0L10 8.183l2.651-3.031c.469-.469 1.228-.469 1.697 0 .469.469.469 1.229 0 1.697l-2.758 3.152 2.758 3.15c.469.469.469 1.229 0 1.698z"\n                />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="large-arrow">\n                <path d="M13.25 10L6.109 2.58c-.268-.27-.268-.707 0-.979.268-.27.701-.27.969 0l7.83 7.908c.268.271.268.709 0 .979l-7.83 7.908c-.268.271-.701.27-.969 0-.268-.269-.268-.707 0-.979L13.25 10z"\n                />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="large-arrow-down">\n            ...

# %%
pprint(resp)
# Out:
# {'access-control-allow-credentials': 'true',
#  'access-control-allow-origin': '*',
#  'connection': 'keep-alive',
#  'content-length': '9593',
#  'content-location': 'https://httpbin.org',
#  'content-type': 'text/html; charset=utf-8',
#  'date': 'Sun, 09 Aug 2020 14:22:08 GMT',
#  'server': 'gunicorn/19.9.0',
#  'status': '200'}

# %%
zalando = 'https://zalando.no'
resp, data = http.request(zalando, method='OPTIONS')

# %%
pprint(resp)
# Out:
# {'-content-encoding': 'gzip',
#  'alt-svc': 'clear',
#  'content-length': '146',
#  'content-type': 'text/html',
#  'date': 'Sun, 09 Aug 2020 14:27:31 GMT',
#  'server': 'nginx',
#  'status': '403',
#  'transfer-encoding': 'chunked',
#  'vary': 'Accept-Encoding',
#  'via': '1.1 google'}

# %%
resp.previous

# %%
data
# Out:
# b'<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
resp, data = http.request(zalando)

# %%
data
# Out:
# b'<!DOCTYPE html>\n<html class="rendering-engine re-master-1654" lang="no-NO">\n<head>\n<meta charset="utf-8"/>\n<meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n<meta http-equiv="Accept-CH" content="DPR, Viewport-Width, Width">\n<link rel="dns-prefetch" href="https://mosaic01.ztat.net/">\n<link rel="dns-prefetch" href="https://mosaic02.ztat.net/">\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n<link rel="stylesheet" href="https://mosaic01.ztat.net/base-assets/5-3-1/assets/style.css" />\n<link rel="stylesheet" href="https://mosaic02.ztat.net/nsg/dx-ui/atom-55.6.0.css" />\n<script src="https://mosaic01.ztat.net/base-assets/require-2.1.22.min.js" crossorigin></script>\n<script>(function(d) {\n  require.config({\n    waitSeconds: 0,\n    onNodeCreated: function(node) {node.src.indexOf(window.location.host) !== -1 ? "" : node.crossOrigin = "anonymous"}\n  });\n  require(d);\n  define(\'z-shop-js-env\', d);\n  var i, arr = [\n    \'safe-fetch\',\n    \'react-addons-css-transition-group\',\n    \'z-shop-ui\',\n    \'z-shop-event-bus\',\n    \'tranzlate\',\n    \'classnames\'\n  ].concat(["react","react-dom"]);\n  while (i = arr.pop()) {\n    (function (dep) { define(dep, d, function (b) { return b[dep]; }) })(i);\n  }\n}([\'https://mosaic01.ztat.net/base-assets/5-3-1/assets/bundle.js\']));</script>\n\n<script>require(["https://mosaic02.ztat.net/rnd/ng/runtime-2832db3a9feda20ed3f6.js","https://mosaic02.ztat.net/rnd/ng/re-commons-chunk-8b958df6-69db-4905-8e5f-d2c93717123c/index-143b47ad09d65c324006.js"]);\n  define(\'commons-chunk\', ["https://mosaic02.ztat.net/rnd/ng/re-commons-chunk-8b958df6-69db-4905-8e5f-d2c93717123c/index-143b47ad09d65c324006.js"], function(common) { return common; })\n  define(\'rendering-engine-api\', ["https://mosaic02.ztat.net/rnd/ng/runtime-2832db3a9feda20ed3f6.js", \'commons-chunk\'], function(runtime) { return runtime.renderingEngineApi; })\n</script>\n<script>(function(a){a.require(["z-shop-event-bus"],function(b){a.zdataLayer=a.zdataLayer||{raw:[],started:!1};var c=function(d){!a.zdataLayer||a.zdataLayer.started?b.off("tracking:event",c):a.zdataLayer.raw.push(d)};b.on("tracking:event",c)})})(window);</script>\n\n<script>window.TailorPipe=function(n,e){var r={},t={},o=n.getElementsByTagName("script"),i=[],a=[];function f(){}var u={onStart:f,onBeforeInit:f,onAfterInit:f,onDone:f};function d(){for(var n,e=o.length-1;e>=0;e--)if((n=o[e]).hasAttribute("data-pipe"))return n.removeAttribute("data-pipe"),n}function c(){0!==i.length||n.readyState&&"complete"!==n.readyState&&"interactive"!==n.readyState||(u.onDone(),u.onDone=f)}function l(n,r){"now"in e&&a.push({name:n,duration:+r,entryType:"tailor",startTime:e.now()})}function p(n){return function(e){var r=u[n];u[n]=function(n,t){r.apply(this,[n,t]),e.apply(this,[n,t])}}}var m=p("onDone");return{placeholder:function(n){r[n]=d()},start:function(n,e,r){t[n]=d(),e&&(i.push(n),u.onStart(r,n),window.require([e]))},end:function(n,e,o){var a=r[n],l=t[n],p=d();if(!l||!p)throw Error("Mismatched pipe for "+n);if(!l.parentNode||!p.parentNode)throw Error("Pipe on detached tree for "+n);var m=null;if(void 0!==a){if(!a.parentNode)throw Error("Detached placeholder "+n);var s=l;do{if((m=s)===p)break;if(!s.nextSibling)throw Error("null nextSibling while filling placeholder "+n);s=s.nextSibling,a.parentNode.insertBefore(m,a)}while(m!==p);a.parentNode.removeChild(a)}for(m=l.nextSibling;m&&1!==m.nodeType;)m=m.nextSibling;m===p&&(m=void 0),l.parentNode.removeChild(l),p.parentNode.removeChild(p),e&&window.require([e],(function(e){!function(n,e,r,t){u.onBeforeInit(t,r);var o,a=n(e),f=function(){i.pop(),u.onAfterInit(t,r),c()};(o=a)&&"function"==typeof o.then?a.then(f,f):f()}((e&&e.__esModule?e.default:e)||f,m,n,o)}))},onStart:p("onStart"),onBeforeInit:p("onBeforeInit"),onAfterInit:p("onAfterInit"),onDone:function(n){m(n),c()},addPerfEntry:l,addTTFMPEntry:function(n){l("ttfmp",n)},getEntries:function(){return a}}}(window.document,window.performance),func ...

# %%
resp, data = http.request(bin_url, method='OPTIONS')

# %%
resp
# Out:
# {'date': 'Sun, 09 Aug 2020 14:29:35 GMT',
#  'content-type': 'text/html; charset=utf-8',
#  'content-length': '0',
#  'connection': 'keep-alive',
#  'server': 'gunicorn/19.9.0',
#  'allow': 'HEAD, OPTIONS, GET',
#  'access-control-allow-origin': '*',
#  'access-control-allow-credentials': 'true',
#  'access-control-allow-methods': 'GET, POST, PUT, DELETE, PATCH, OPTIONS',
#  'access-control-max-age': '3600',
#  'status': '200',
#  'content-location': 'https://httpbin.org'}
